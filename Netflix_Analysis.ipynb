# %% [markdown]
# # 📺 Netflix Data Analysis
#
# ### What this project is about:
# I took a dataset of Netflix titles and did some basic analysis to understand what kind of content they have — like whether they prefer movies or TV shows, which countries contribute the most, what genres are popular, and how Netflix has grown over the years.
#
# ---
#
# ## 🔍 Key Things I Found:
# - Netflix has way more movies than TV shows.
# - The United States is the top country producing content on Netflix.
# - There’s been a huge rise in content after 2015
# - Genres like Drama, **International Movies, and **Family Shows are the most common.
#
# ---
#
# ### Tools I Used:
# - Python with Pandas, Matplotlib, and Seaborn
# - Jupyter Notebook
# - Dataset from Kaggle
#
# ---
#
# ## 📁 Files in this project:
# - `Netflix_Analysis.ipynb` – Jupyter notebook with all the analysis
# - `netflix_titles.csv` – The raw dataset (or you can download it from Kaggle)
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv("netflix_titles.csv", encoding='ISO-8859-1')  # Use encoding for safety
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("netflix_titles.csv", encoding='ISO-8859-1')
df.head()

print(df.columns)
print(df.isnull().sum())

df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
print(df['date_added'].isna().sum())

df = df.dropna(subset=['date_added'])

df['year_added'] = df['date_added'].dt.year
df['year_added'].value_counts().sort_index().plot(kind='line', title='Titles Added by Year')
plt.ylabel('Number of Titles')
plt.show()

df['listed_in'].str.split(',').explode().str.strip().value_counts().head(10).plot(kind='barh', title='Top 10 Genres')
plt.show()
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64
# 98
